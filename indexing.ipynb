# %%
str1="good morning"
str1[0]
# Out:
# 'g'

# %%
str1[2]
# Out:
# 'o'

# %%
str1[-1]
# Out:
# 'g'

# %%
str1[-2]
# Out:
# 'n'

# %%
str1[-3]
# Out:
# 'i'

# %%
str1[-4]
# Out:
# 'n'

# %%
str1[-9]
# Out:
# 'd'

# %%
str1[-5]
# Out:
# 'r'

# %%
str1[-6]
# Out:
# 'o'

# %%
str1[-7]
# Out:
# 'm'

# %%
str1[-10]
# Out:
# 'o'

# %%
str1[-11]
# Out:
# 'o'

# %%
str1[-12]
# Out:
# 'g'

# %%
str1[-13]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 str1[-13]
#
# IndexError: string index out of range

# %%
str2="HELLO PYTHON"
str2[0:4]
# Out:
# 'HELL'

# %%
str2[1:7]
# Out:
# 'ELLO P'

# %%
str2[:]
# Out:
# 'HELLO PYTHON'

# %%
str2[2:]
# Out:
# 'LLO PYTHON'

# %%
str2[:7]
# Out:
# 'HELLO P'

# %% [markdown]
# ## str2[4:9]

# %%
str2[

# %%
str2[0:9:2]
# Out:
# 'HLOPT'

# %% [markdown]
# ###

# %%
str2[3:10:3]
# Out:
# 'LPH'

# %%
str2[::-1]
# Out:
# 'NOHTYP OLLEH'

# %%
fname="ajay"
lname="kumar"
full_name=fname+lname
print(full_name)
# Out:
# ajaykumar

# %%
x="amith"+" "+"kumar"
print(x)
# Out:
# amith kumar

# %%
fname="ajay"
"j"in fname
# Out:
# True
